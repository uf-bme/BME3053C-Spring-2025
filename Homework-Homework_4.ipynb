# %% [markdown]
# <a href="https://colab.research.google.com/github/maucerit/BME3053C-Spring-2025/blob/main/Homework-Homework_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
anscombe_df = pd.read_json('/content/sample_data/anscombe.json')
grouped_df = anscombe_df.groupby(['Series'])
grouped_df.describe()
grouped_df.boxplot()
grouped_df.plot.scatter(x='X', y='Y',c='blue')
#Data set I in the scatter plot shows a linear relationship with the points with the points closely but not perfectly aligned, allowing this data to be shown using a linear regression model. The box plot aligns with this as it the x and y values are both within the same range however unlike the scatter pot, the box plot does not show a clear linear relationship while it does show that there are no significant outliers.
#While both the scatter plot and the box plot for Dataset II show the same mean and max values, however the scatter plot does not clearly show the outlier value as the box plot does and also, the box plot does not show the quadratic relationship that can be seen in the scatter plot. Instead, the box plot shows a smaller domain with no clear correlation to either a linear or quadratic relationship.
#As for Dataset III, both graphs show a clear small range of data points, however the scatter plot clearly highlights the outlier better than the box plot as it shows how perfectly linear the data is and then the presence of an outlier that completely disobeys the relationship of the rest of the data.
#Then data set Dataset IV clearly shows in both the scatter plot and the box plot that there are multiple y values for similar x values, however the box plot does not indicate that there is only one x value to these y values like the scatter plot shows. Therefore, while the box plot shows correlation between the x and y values, it does not show the vertical relationship between data as does the scatter plot. They also both clearly show the presence of an outlier.
#From this assignment I have learned that while box plots show spread, variability and outliers they do not show relationships between x and y values as does scatter plots which clearly depict trends, patterns and relationships.
# Out:
# Series
# I      Axes(0.125,0.11;0.775x0.77)
# II     Axes(0.125,0.11;0.775x0.77)
# III    Axes(0.125,0.11;0.775x0.77)
# IV     Axes(0.125,0.11;0.775x0.77)
# dtype: object
